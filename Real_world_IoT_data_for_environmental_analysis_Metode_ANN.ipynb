# %% [markdown]
# ## IMPORT LIBRARY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv('Sensors_data.csv')

# %% [markdown]
# mendeskripsikan file menjadi "data" dan menhapus "Unnamed: 0"

# %%
data = data.drop(['Unnamed: 0', ], axis=1)
print (data)
# Out:
#                        _time  Heat_index   Humidity  Temperature
# 0       2022-04-13T21:38:00Z   26.389790  32.400000    26.800000
# 1       2022-04-13T21:39:00Z   26.391128  32.433333    26.800000
# 2       2022-04-13T21:40:00Z   26.377855  32.100000    26.800000
# 3       2022-04-13T21:41:00Z   26.401618  31.916667    26.850000
# 4       2022-04-13T21:42:00Z   26.414282  31.716667    26.883333
# ...                      ...         ...        ...          ...
# 385867  2023-01-20T01:12:00Z   20.359950  46.133333    21.000000
# 385868  2023-01-20T01:13:00Z   20.359080  46.100000    21.000000
# 385869  2023-01-20T01:14:00Z   20.363430  46.266667    21.000000
# 385870  2023-01-20T01:15:00Z   20.357340  46.033333    21.000000
# 385871  2023-01-20T01:16:00Z   20.357514  46.040000    21.000000
#
# [385872 rows x 4 columns]

# %% [markdown]
# ## Data Explore Analysis

# %% [markdown]
# Melihat info data

# %%
data.describe()
# Out:
#           Heat_index       Humidity    Temperature
# count  385872.000000  385872.000000  385872.000000
# mean       23.096529      52.172995      23.350587
# std         2.657446      11.013673       2.558366
# min        15.753450      17.983333      16.400000
# 25%        21.541057      45.350000      21.733333
# 50%        23.203913      53.183333      23.366667
# 75%        25.036140      59.200000      25.200000
# max        30.089642      96.300000      29.933333

# %% [markdown]
# Mengecek jumlah data yang hilang

# %%
data.isnull().sum()/len(data)
# Out:
# _time          0.0
# Heat_index     0.0
# Humidity       0.0
# Temperature    0.0
# dtype: float64

# %% [markdown]
# Mengecek jumlah data yang valid

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385872 entries, 0 to 385871
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   _time        385872 non-null  object
#  1   Heat_index   385872 non-null  float64
#  2   Humidity     385872 non-null  float64
#  3   Temperature  385872 non-null  float64
# dtypes: float64(3), object(1)
# memory usage: 11.8+ MB

# %% [markdown]
# Mengubah variabel "_time" yang berupa object menjadi data tanggal dan waktu

# %%
# Ubah data "_time" menjadi datetime
data['_time'] = pd.to_datetime(data['_time'])
data.set_index('_time', inplace=True)

# %% [markdown]
# membuat plot data

# %%
for column in data.columns:
    plt.figure(figsize=(14, 6))
    data[column].plot()
    plt.title(column)
    plt.show()

# %% [markdown]
# memperhalus plot

# %%
monthly_data = data.resample('M').mean()
for column in monthly_data.columns:
    plt.figure(figsize=(14, 6))
    monthly_data[column].plot()
    plt.title(column)
    plt.show()

# %% [markdown]
# membuat plot antar data untuk semua data

# %%
sns.pairplot(data)

# %%
data.hist(bins=50,figsize=(20,15))
plt.savefig("attribute_histogram_plots")
plt.show()

# %% [markdown]
# membuat matrix kolerasi

# %%
numeric_data = data.select_dtypes(include=[np.number])
correlation_matrix = numeric_data.corr()
fig = plt.subplots(figsize=(20, 16))
sns.heatmap(data[data.columns[0:13].tolist()].corr(), annot=True, fmt='.2f', vmin=-1.0, vmax=1.0, center=0)
plt.title('korelasi data', fontsize=12)
plt.show()

# %% [markdown]
# ## Split Data into test and train

# %% [markdown]
# membagi DataFrame data menjadi dua bagian: input (X) dan output (y)

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %% [markdown]
# ## Data Scalling

# %% [markdown]
# menerapkan minmax scaler

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# membagi data test dan data train (data test = 20 % dan data train = 80%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %% [markdown]
# ## LINEAR REGRESSION

# %%
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.997827613764311
# Test score 0.9977907105621123

# %% [markdown]
# melakukan prediksi dari linear regression dan memperlihatkan hasilnya

# %%
y_pred = lreg.predict(X_test)
print (y_pred)
# Out:
# [[0.84080128]
#  [0.58873245]
#  [0.53532441]
#  ...
#  [0.09540154]
#  [0.81123144]
#  [0.39990402]]

# %% [markdown]
# ## ANN Metode

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])
ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])
history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 9.3360e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0225e-04 - val_mean_absolute_error: 0.0064
# Epoch 2/50
# 7718/7718 [==============================] - 15s 2ms/step - loss: 5.8529e-05 - mean_absolute_error: 0.0042 - val_loss: 4.1435e-05 - val_mean_absolute_error: 0.0034
# Epoch 3/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 4.1585e-05 - mean_absolute_error: 0.0038 - val_loss: 3.4483e-05 - val_mean_absolute_error: 0.0034
# Epoch 4/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 2.7718e-05 - mean_absolute_error: 0.0031 - val_loss: 1.9909e-05 - val_mean_absolute_error: 0.0023
# Epoch 5/50
# 7718/7718 [==============================] - 15s 2ms/step - loss: 1.8666e-05 - mean_absolute_error: 0.0025 - val_loss: 1.2161e-05 - val_mean_absolute_error: 0.0018
# Epoch 6/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.1739e-05 - mean_absolute_error: 0.0021 - val_loss: 1.2400e-05 - val_mean_absolute_error: 0.0028
# Epoch 7/50
# 7718/7718 [==============================] - 15s 2ms/step - loss: 9.1595e-06 - mean_absolute_error: 0.0019 - val_loss: 7.0199e-06 - val_mean_absolute_error: 0.0015
# Epoch 8/50
# 7718/7718 [==============================] - 18s 2ms/step - loss: 7.6643e-06 - mean_absolute_error: 0.0017 - val_loss: 6.8765e-06 - val_mean_absolute_error: 0.0011
# Epoch 9/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 6.5994e-06 - mean_absolute_error: 0.0015 - val_loss: 6.1404e-06 - val_mean_absolute_error: 0.0018
# Epoch 10/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 6.0620e-06 - mean_absolute_error: 0.0015 - val_loss: 5.8436e-06 - val_mean_absolute_error: 0.0018
# Epoch 11/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 5.5284e-06 - mean_absolute_error: 0.0014 - val_loss: 4.2763e-06 - val_mean_absolute_error: 8.1837e-04
# Epoch 12/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 5.2718e-06 - mean_absolute_error: 0.0014 - val_loss: 4.2923e-06 - val_mean_absolute_error: 6.9677e-04
# Epoch 13/50
# 7718/7718 [==============================] - 20s 3ms/step - loss: 5.0259e-06 - mean_absolute_error: 0.0013 - val_loss: 3.5178e-06 - val_mean_absolute_error: 6.8118e-04
# Epoch 14/50
# 7718/7718 [==============================] - 24s 3ms/step - loss: 4.5517e-06 - mean_absolute_error: 0.0013 - val_loss: 1.3848e-05 - val_mean_absolute_error: 0.0034
# Epoch 15/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 3.9197e-06 - mean_absolute_error: 0.0012 - val_loss: 8.2674e-06 - val_mean_absolute_error: 0.0026
# Epoch 16/50
# 7718/7718 [==============================] - 20s 3ms/step - loss: 3.6841e-06 - mean_absolute_error: 0.0012 - val_loss: 2.5771e-06 - val_mean_absolute_error: 8.4189e-04
# Epoch 17/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 3.4184e-06 - mean_absolute_error: 0.0011 - val_loss: 2.5927e-06 - val_mean_absolute_error: 8.1709e-04
# Epoch 18/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 3.2658e-06 - mean_absolute_error: 0.0011 - val_loss: 2.4957e-06 - val_mean_absolute_error: 6.9304e-04
# Epoch 19/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 3.1448e-06 - mean_absolute_error: 0.0011 - val_loss: 5.7210e-06 - val_mean_absolute_error: 0.0022
# Epoch 20/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.7530e-06 - mean_absolute_error: 0.0010 - val_loss: 1.8740e-06 - val_mean_absolute_error: 6.1390e-04
# Epoch 21/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.5393e-06 - mean_absolute_error: 0.0010 - val_loss: 2.7946e-06 - val_mean_absolute_error: 0.0013
# Epoch 22/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 2.5274e-06 - mean_absolute_error: 9.9530e-04 - val_loss: 2.9702e-06 - val_mean_absolute_error: 0.0015
# Epoch 23/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.4499e-06 - mean_absolute_error: 9.7689e-04 - val_loss: 1.3348e-06 - val_mean_absolute_error: 3.3345e-04
# Epoch 24/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.3882e-06 - mean_absolute_error: 9.6856e-04 - val_loss: 2.3698e-06 - val_mean_absolute_error: 9.9080e-04
# Epoch 25/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 2.3302e-06 - mean_absolute_error: 9.5323e-04 - val_loss: 1.5003e-06 - val_mean_absolute_error: 7.0023e-04
# Epoch 26/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.2694e-06 - mean_absolute_error: 9.4805e-04 - val_loss: 2.0595e-06 - val_mean_absolute_error: 8.1408e-04
# Epoch 27/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.3115e-06 - mean_absolute_error: 9.5590e-04 - val_loss: 2.1058e-06 - val_mean_absolute_error: 0.0012
# Epoch 28/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.2336e-06 - mean_absolute_error: 9.4072e-04 - val_loss: 6.1992e-06 - val_mean_absolute_error: 0.0023
# Epoch 29/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 2.1961e-06 - mean_absolute_error: 9.3025e-04 - val_loss: 2.0815e-06 - val_mean_absolute_error: 0.0011
# Epoch 30/50
# 7718/7718 [==============================] - 17s 2ms/step - loss: 2.2249e-06 - mean_absolute_error: 9.3355e-04 - val_loss: 4.4814e-06 - val_mean_absolute_error: 0.0016
# Epoch 31/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.1852e-06 - mean_absolute_error: 9.1881e-04 - val_loss: 3.4192e-06 - val_mean_absolute_error: 0.0016
# Epoch 32/50
# 7718/7718 [==============================] - 18s 2ms/step - loss: 2.1418e-06 - mean_absolute_error: 9.1059e-04 - val_loss: 2.7128e-06 - val_mean_absolute_error: 0.0014
# Epoch 33/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0953e-06 - mean_absolute_error: 9.0387e-04 - val_loss: 2.1333e-06 - val_mean_absolute_error: 0.0012
# Epoch 34/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0913e-06 - mean_absolute_error: 8.9594e-04 - val_loss: 1.4466e-06 - val_mean_absolute_error: 5.9404e-04
# Epoch 35/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0692e-06 - mean_absolute_error: 8.9219e-04 - val_loss: 2.9504e-06 - val_mean_absolute_error: 0.0015
# Epoch 36/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0799e-06 - mean_absolute_error: 9.0233e-04 - val_loss: 3.3935e-06 - val_mean_absolute_error: 0.0016
# Epoch 37/50
# 7718/7718 [==============================] - 23s 3ms/step - loss: 2.0699e-06 - mean_absolute_error: 8.9842e-04 - val_loss: 1.4556e-06 - val_mean_absolute_error: 4.9214e-04
# Epoch 38/50
# 7718/7718 [==============================] - 25s 3ms/step - loss: 2.0513e-06 - mean_absolute_error: 8.8923e-04 - val_loss: 1.3852e-06 - val_mean_absolute_error: 6.9802e-04
# Epoch 39/50
# 7718/7718 [==============================] - 19s 2ms/step - loss: 1.9592e-06 - mean_absolute_error: 8.6474e-04 - val_loss: 1.2265e-06 - val_mean_absolute_error: 5.3289e-04
# Epoch 40/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0445e-06 - mean_absolute_error: 8.9167e-04 - val_loss: 1.1643e-06 - val_mean_absolute_error: 4.2882e-04
# Epoch 41/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0112e-06 - mean_absolute_error: 8.8579e-04 - val_loss: 1.3202e-06 - val_mean_absolute_error: 5.5595e-04
# Epoch 42/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9730e-06 - mean_absolute_error: 8.7166e-04 - val_loss: 4.3145e-06 - val_mean_absolute_error: 0.0019
# Epoch 43/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 2.0131e-06 - mean_absolute_error: 8.8272e-04 - val_loss: 1.9955e-06 - val_mean_absolute_error: 0.0010
# Epoch 44/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9656e-06 - mean_absolute_error: 8.6662e-04 - val_loss: 1.4955e-06 - val_mean_absolute_error: 8.7751e-04
# Epoch 45/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9571e-06 - mean_absolute_error: 8.7176e-04 - val_loss: 1.4236e-06 - val_mean_absolute_error: 6.2622e-04
# Epoch 46/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9380e-06 - mean_absolute_error: 8.7435e-04 - val_loss: 3.5976e-06 - val_mean_absolute_error: 0.0015
# Epoch 47/50
# 7718/7718 [==============================] - 17s 2ms/step - loss: 1.9060e-06 - mean_absolute_error: 8.5166e-04 - val_loss: 3.5505e-06 - val_mean_absolute_error: 0.0016
# Epoch 48/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9293e-06 - mean_absolute_error: 8.6213e-04 - val_loss: 2.5116e-06 - val_mean_absolute_error: 0.0010
# Epoch 49/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9124e-06 - mean_absolute_error: 8.6181e-04 - val_loss: 2.2252e-06 - val_mean_absolute_error: 0.0011
# Epoch 50/50
# 7718/7718 [==============================] - 16s 2ms/step - loss: 1.9250e-06 - mean_absolute_error: 8.5931e-04 - val_loss: 1.8202e-06 - val_mean_absolute_error: 0.0010

# %% [markdown]
# membuat plot tabel "loss" dan "acccuracy"

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# melakukan prediksi dari ANN dan memperlihatkan hasilnya

# %%
ann_y_pred = ann.predict(X_test)

print(ann_y_pred)
# Out:
# 2412/2412 [==============================] - 3s 1ms/step
# [[0.8589595 ]
#  [0.5922548 ]
#  [0.53796446]
#  ...
#  [0.09635587]
#  [0.78516096]
#  [0.39975676]]

# %% [markdown]
# mengevaluasi prediksi yang dilakukan

# %%
ann.evaluate(X_test, y_test)
# Out:
# 2412/2412 [==============================] - 3s 1ms/step - loss: 1.8355e-06 - mean_absolute_error: 0.0010
# [1.8355189013163908e-06, 0.0010202040430158377]

# %% [markdown]
# membuat plot perbandingan model

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %% [markdown]
# ## Make Result Report

# %% [markdown]
# Membuat confusion matrix

# %%
y_pred_binary = (y_pred > 0.5).astype(int)
cm = confusion_matrix(y_test > 0.5, y_pred_binary)

plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# membuat classification report

# %%
print(classification_report(y_test > 0.5, y_pred_binary))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00     36035
#         True       1.00      1.00      1.00     41140
#
#     accuracy                           1.00     77175
#    macro avg       1.00      1.00      1.00     77175
# weighted avg       1.00      1.00      1.00     77175

# %%
lr_predictions = lreg.predict(X_test)
ann_predictions = ann.predict(X_test)

lr_accuracy = r2_score(y_test, lr_predictions)
ann_accuracy = r2_score(y_test, ann_predictions)

lr_accuracy_percent = lr_accuracy * 100
ann_accuracy_percent = ann_accuracy * 100

print("Akurasi Linear Regression: {:.2f}%".format(lr_accuracy_percent))
print("Akurasi ANN: {:.2f}%".format(ann_accuracy_percent))

models = ['Linear Regression', 'ANN']
accuracy = [lr_accuracy_percent, ann_accuracy_percent]

plt.figure(figsize=(10, 50))
plt.bar(models, accuracy, color=['blue', 'green'])
plt.xlabel('Model')
plt.ylabel('Akurasi (%)')
plt.title('Perbandingan Akurasi Model')
plt.show()
# Out:
# 2412/2412 [==============================] - 4s 2ms/step
# Akurasi Linear Regression: 99.78%
# Akurasi ANN: 99.99%

# %%
data = pd.read_csv('Sensors_data.csv')
data['_time'] = pd.to_datetime(data['_time'])


data.set_index('_time', inplace=True)
timestamp = timestamp_input = input("Masukkan timestamp (format: YYYY-MM-DDTHH:MM:SSZ): ")
data_at_timestamp = data.loc[timestamp]
print(data_at_timestamp)
high_temp_data = data[data['Temperature'] > 30]
print(high_temp_data)
# Out:
# Masukkan timestamp (format: YYYY-MM-DDTHH:MM:SSZ): 2023-01-20T01:13:00Z
# Unnamed: 0     385868.00000
# Heat_index         20.35908
# Humidity           46.10000
# Temperature        21.00000
# Name: 2023-01-20 01:13:00+00:00, dtype: float64
# Empty DataFrame
# Columns: [Unnamed: 0, Heat_index, Humidity, Temperature]
# Index: []
